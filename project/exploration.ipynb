# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Specify the path to your Excel file
co2_emmision_df = '../data/CO2 emission by countries.csv'
share_ele_df = '../data/share-electricity-renewables.csv'
encoding_type = 'ISO-8859-1'

# Read the Excel file into a DataFrame
df1 = pd.read_csv(co2_emmision_df, encoding=encoding_type)
df2 = pd.read_csv(share_ele_df, encoding=encoding_type)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59620 entries, 0 to 59619
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Country              59620 non-null  object
#  1   Code                 57452 non-null  object
#  2   Calling Code         56097 non-null  object
#  3   Year                 59620 non-null  int64
#  4   CO2 emission (Tons)  59620 non-null  float64
#  5   Population(2022)     53116 non-null  float64
#  6   Area                 55284 non-null  float64
#  7   % of World           55284 non-null  object
#  8   Density(km2)         53116 non-null  object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 4.1+ MB

# %%
df1.describe()
# Out:
#                Year  CO2 emission (Tons)  Population(2022)          Area
# count  59620.000000         5.962000e+04      5.311600e+04  5.528400e+04
# mean    1885.000000         1.034774e+09      3.992260e+07  6.522073e+05
# std       78.231085         1.041652e+10      1.482365e+08  1.865483e+06
# min     1750.000000         0.000000e+00      1.131200e+04  2.100000e+01
# 25%     1817.000000         0.000000e+00      1.770414e+06  1.770450e+04
# 50%     1885.000000         0.000000e+00      8.673095e+06  1.103815e+05
# 75%     1953.000000         8.715092e+06      2.862920e+07  4.925730e+05
# max     2020.000000         4.170000e+11      1.425887e+09  1.709824e+07

# %%
df1.head()
# Out:
#        Country Code Calling Code  Year  CO2 emission (Tons)  Population(2022)
# 0  Afghanistan   AF           93  1750                  0.0        41128771.0  \
# 1  Afghanistan   AF           93  1751                  0.0        41128771.0
# 2  Afghanistan   AF           93  1752                  0.0        41128771.0
# 3  Afghanistan   AF           93  1753                  0.0        41128771.0
# 4  Afghanistan   AF           93  1754                  0.0        41128771.0
#
#        Area % of World Density(km2)
# 0  652230.0      0.40%       63/km²
# 1  652230.0      0.40%       63/km²
# 2  652230.0      0.40%       63/km²
# 3  652230.0      0.40%       63/km²
# 4  652230.0      0.40%       63/km²

# %%
df2.describe()
# Out:
#               Year  Renewables (% electricity)
# count  6832.000000                 6832.000000
# mean   2007.207845                   30.139900
# std       9.377810                   30.689094
# min    1985.000000                    0.000000
# 25%    2001.000000                    3.839269
# 50%    2008.000000                   18.518672
# 75%    2015.000000                   51.724138
# max    2022.000000                  100.000015

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6832 entries, 0 to 6831
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Entity                      6832 non-null   object
#  1   Code                        5689 non-null   object
#  2   Year                        6832 non-null   int64
#  3   Renewables (% electricity)  6832 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 213.6+ KB

# %%
df2= df2.rename(columns={'Renewables (% electricity)': 'Renewables'})

# %%
df2.tail()
# Out:
#         Entity Code  Year  Renewables
# 6827  Zimbabwe  ZWE  2017   58.503407
# 6828  Zimbabwe  ZWE  2018   59.412407
# 6829  Zimbabwe  ZWE  2019   55.582527
# 6830  Zimbabwe  ZWE  2020   55.204216
# 6831  Zimbabwe  ZWE  2021   55.043587

# %%
df2['Code'].isnull().sum()
# Out:
# 1143

# %%
latest_year_idx = df2.groupby('Entity')['Year'].idxmax()
latest_year_renewables = df2.loc[latest_year_idx]

# %%
# devide the dataframe into the four part for the better visualization
num_rows = len(latest_year_renewables)

# Divide the DataFrame into four equal parts
equal_parts = np.array_split(latest_year_renewables, 4)

# Access each part
part1, part2, part3, part4 = equal_parts[0], equal_parts[1], equal_parts[2], equal_parts[3]

# %%
plt.figure(figsize=(12, 6))
plt.bar(part1['Entity'], part1['Renewables'])
plt.xlabel('Entity')
plt.ylabel('Renewables')
plt.title('Renewables for Each Entity (Latest Year)')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.bar(part2['Entity'], part2['Renewables'])
plt.xlabel('Entity')
plt.ylabel('Renewables')
plt.title('Renewables for Each Entity (Latest Year)')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.bar(part3['Entity'], part3['Renewables'])
plt.xlabel('Entity')
plt.ylabel('Renewables')
plt.title('Renewables for Each Entity (Latest Year)')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.bar(part4['Entity'], part4['Renewables'])
plt.xlabel('Entity')
plt.ylabel('Renewables')
plt.title('Renewables for Each Entity (Latest Year)')
plt.xticks(rotation=90)
plt.show()
